# %%
import sys
sys.path.append(r"Z:\\BioMotionAnlyze\analyze")

# %%
import pymovements as pm
from datasetDef import load_dataset

# check if folder exists
base_path = r"Z:\BioMotionAnlyze\analyze\data\pymovement data\202511_typeA\rt"

dataset = load_dataset(base_path)
# dataset = load_dataset(r"Z:\\BioMotionAnlyze\analyze\data\pymovement data\")
# dataset = load_dataset(r"Z:\BioMotionAnlyze\analyze")
# Out:
#   0%|          | 0/1540 [00:00<?, ?it/s]

# %%
#dir(dataset)
dataset.fileinfo
# Out:
# {'gaze': shape: (1_540, 3)
#  ┌─────────────────────────────────┬──────────┬─────────────────────────────────┐
#  │ subject_id                      ┆ trial_id ┆ filepath                        │
#  │ ---                             ┆ ---      ┆ ---                             │
#  │ str                             ┆ i64      ┆ str                             │
#  ╞═════════════════════════════════╪══════════╪═════════════════════════════════╡
#  │ 2025-11-25(122)-r0025-eyeTrcAn… ┆ 0        ┆ trial_2025-11-25(122)-r0025-ey… │
#  │ 2025-11-25(122)-r0025-eyeTrcAn… ┆ 1        ┆ trial_2025-11-25(122)-r0025-ey… │
#  │ 2025-11-25(122)-r0025-eyeTrcAn… ┆ 10       ┆ trial_2025-11-25(122)-r0025-ey… │
#  │ 2025-11-25(122)-r0025-eyeTrcAn… ┆ 11       ┆ trial_2025-11-25(122)-r0025-ey… │
#  │ 2025-11-25(122)-r0025-eyeTrcAn… ┆ 12       ┆ trial_2025-11-25(122)-r0025-ey… │
#  │ …                               ┆ …        ┆ …                               │
# ...

# %%
dataset.pix2deg()
dataset.pos2vel(method='savitzky_golay', degree=2, window_length=7)

dataset.gaze[0]
# Out:
# ...
#   0%|          | 0/1540 [00:00<?, ?it/s]
# Experiment(screen=Screen(width_px=1920, height_px=1080, width_cm=72.0, height_cm=40.5, distance_cm=57.0, origin='upper left'), eyetracker=EyeTracker(sampling_rate=1000, left=None, right=None, model=None, version=None, vendor=None, mount=None))
# shape: (4_374, 9)
# ┌──────┬─────────────┬────────┬────────────┬───┬──────────┬─────────────┬─────────────┬────────────┐
# │ time ┆ stimulus_in ┆ choice ┆ subject_id ┆ … ┆ filename ┆ pixel       ┆ position    ┆ velocity   │
# │ ---  ┆ dex         ┆ ---    ┆ ---        ┆   ┆ ---      ┆ ---         ┆ ---         ┆ ---        │
# │ i64  ┆ ---         ┆ i64    ┆ str        ┆   ┆ str      ┆ list[f64]   ┆ list[f64]   ┆ list[f64]  │
# │      ┆ f64         ┆        ┆            ┆   ┆          ┆             ┆             ┆            │
# ╞══════╪═════════════╪════════╪════════════╪═══╪══════════╪═════════════╪═════════════╪════════════╡
# ...

# %%
dataset.save_preprocessed()
# Out:
#   0%|          | 0/1540 [00:00<?, ?it/s]
